# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mpl_toolkits import mplot3d
# %matplotlib inline
carprice=pd.read_csv("data.csv")

# %%
type(carprice)
# Out:
# pandas.core.frame.DataFrame

# %%
carprice.head(10)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
# 6               6.0            MANUAL  rear wheel drive              2.0
# 7               6.0            MANUAL  rear wheel drive              2.0
# 8               6.0            MANUAL  rear wheel drive              2.0
# 9               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
# 5                     Luxury,Performance      Compact         Coupe
# 6                     Luxury,Performance      Compact   Convertible
# 7                Luxury,High-Performance      Compact         Coupe
# 8                                 Luxury      Compact   Convertible
# 9                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500
# 5           28        18        3916  31200
# 6           26        17        3916  44100
# 7           28        20        3916  39300
# 8           28        18        3916  36900
# 9           27        18        3916  37200

# %%
carprice["Make"].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
df=carprice

# %%
carprice
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# 11         BMW    1 Series  2013     premium unleaded (required)      230.0
# 12         BMW    1 Series  2013     premium unleaded (required)      300.0
# 13         BMW    1 Series  2013     premium unleaded (required)      230.0
# 14         BMW    1 Series  2013     premium unleaded (required)      230.0
# 15         BMW    1 Series  2013     premium unleaded (required)      320.0
# 16         BMW    1 Series  2013     premium unleaded (required)      320.0
# 17        Audi         100  1992                regular unleaded      172.0
# 18        Audi         100  1992                regular unleaded      172.0
# 19        Audi         100  1992                regular unleaded      172.0
# 20        Audi         100  1992                regular unleaded      172.0
# 21        Audi         100  1992                regular unleaded      172.0
# 22        Audi         100  1993                regular unleaded      172.0
# 23        Audi         100  1993                regular unleaded      172.0
# 24        Audi         100  1993                regular unleaded      172.0
# 25        Audi         100  1993                regular unleaded      172.0
# 26        Audi         100  1993                regular unleaded      172.0
# 27        Audi         100  1994                regular unleaded      172.0
# 28        Audi         100  1994                regular unleaded      172.0
# 29        Audi         100  1994                regular unleaded      172.0
# ...        ...         ...   ...                             ...        ...
# 11884      BMW          Z3  2001     premium unleaded (required)      225.0
# 11885      BMW          Z3  2001     premium unleaded (required)      184.0
# 11886      BMW          Z3  2001     premium unleaded (required)      225.0
# 11887      BMW          Z3  2002     premium unleaded (required)      225.0
# 11888      BMW          Z3  2002     premium unleaded (required)      184.0
# 11889      BMW          Z3  2002     premium unleaded (required)      225.0
# 11890      BMW        Z4 M  2007     premium unleaded (required)      330.0
# 11891      BMW        Z4 M  2007     premium unleaded (required)      330.0
# 11892      BMW        Z4 M  2008     premium unleaded (required)      330.0
# 11893      BMW        Z4 M  2008     premium unleaded (required)      330.0
# 11894      BMW          Z4  2014     premium unleaded (required)      240.0
# 11895      BMW          Z4  2014     premium unleaded (required)      300.0
# 11896      BMW          Z4  2014     premium unleaded (required)      335.0
# 11897      BMW          Z4  2015     premium unleaded (required)      240.0
# 11898      BMW          Z4  2015     premium unleaded (required)      300.0
# 11899      BMW          Z4  2015     premium unleaded (required)      335.0
# 11900      BMW          Z4  2016     premium unleaded (required)      300.0
# 11901      BMW          Z4  2016     premium unleaded (required)      240.0
# 11902      BMW          Z4  2016     premium unleaded (required)      335.0
# 11903      BMW          Z8  2001     premium unleaded (required)      394.0
# 11904      BMW          Z8  2002     premium unleaded (required)      394.0
# 11905      BMW          Z8  2003     premium unleaded (required)      394.0
# 11906    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11907    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11908    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# 5                   6.0            MANUAL   rear wheel drive              2.0
# 6                   6.0            MANUAL   rear wheel drive              2.0
# 7                   6.0            MANUAL   rear wheel drive              2.0
# 8                   6.0            MANUAL   rear wheel drive              2.0
# 9                   6.0            MANUAL   rear wheel drive              2.0
# 10                  6.0            MANUAL   rear wheel drive              2.0
# 11                  6.0            MANUAL   rear wheel drive              2.0
# 12                  6.0            MANUAL   rear wheel drive              2.0
# 13                  6.0            MANUAL   rear wheel drive              2.0
# 14                  6.0            MANUAL   rear wheel drive              2.0
# 15                  6.0            MANUAL   rear wheel drive              2.0
# 16                  6.0            MANUAL   rear wheel drive              2.0
# 17                  6.0            MANUAL  front wheel drive              4.0
# 18                  6.0            MANUAL  front wheel drive              4.0
# 19                  6.0         AUTOMATIC    all wheel drive              4.0
# 20                  6.0            MANUAL  front wheel drive              4.0
# 21                  6.0            MANUAL    all wheel drive              4.0
# 22                  6.0            MANUAL  front wheel drive              4.0
# 23                  6.0         AUTOMATIC    all wheel drive              4.0
# 24                  6.0            MANUAL  front wheel drive              4.0
# 25                  6.0            MANUAL  front wheel drive              4.0
# 26                  6.0            MANUAL    all wheel drive              4.0
# 27                  6.0         AUTOMATIC  front wheel drive              4.0
# 28                  6.0            MANUAL    all wheel drive              4.0
# 29                  6.0            MANUAL  front wheel drive              4.0
# ...                 ...               ...                ...              ...
# 11884               6.0            MANUAL   rear wheel drive              2.0
# 11885               6.0            MANUAL   rear wheel drive              2.0
# 11886               6.0            MANUAL   rear wheel drive              2.0
# 11887               6.0            MANUAL   rear wheel drive              2.0
# 11888               6.0            MANUAL   rear wheel drive              2.0
# 11889               6.0            MANUAL   rear wheel drive              2.0
# 11890               6.0            MANUAL   rear wheel drive              2.0
# 11891               6.0            MANUAL   rear wheel drive              2.0
# 11892               6.0            MANUAL   rear wheel drive              2.0
# 11893               6.0            MANUAL   rear wheel drive              2.0
# 11894               4.0            MANUAL   rear wheel drive              2.0
# 11895               6.0            MANUAL   rear wheel drive              2.0
# 11896               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11897               4.0            MANUAL   rear wheel drive              2.0
# 11898               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11899               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11900               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11901               4.0            MANUAL   rear wheel drive              2.0
# 11902               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11903               8.0            MANUAL   rear wheel drive              2.0
# 11904               8.0            MANUAL   rear wheel drive              2.0
# 11905               8.0            MANUAL   rear wheel drive              2.0
# 11906               6.0         AUTOMATIC    all wheel drive              4.0
# 11907               6.0         AUTOMATIC    all wheel drive              4.0
# 11908               6.0         AUTOMATIC    all wheel drive              4.0
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# 5                         Luxury,Performance      Compact          Coupe
# 6                         Luxury,Performance      Compact    Convertible
# 7                    Luxury,High-Performance      Compact          Coupe
# 8                                     Luxury      Compact    Convertible
# 9                                     Luxury      Compact    Convertible
# 10                   Luxury,High-Performance      Compact          Coupe
# 11                        Luxury,Performance      Compact          Coupe
# 12                        Luxury,Performance      Compact    Convertible
# 13                                    Luxury      Compact    Convertible
# 14                        Luxury,Performance      Compact          Coupe
# 15                   Luxury,High-Performance      Compact    Convertible
# 16                   Luxury,High-Performance      Compact          Coupe
# 17                                    Luxury      Midsize          Sedan
# 18                                    Luxury      Midsize          Sedan
# 19                                    Luxury      Midsize          Wagon
# 20                                    Luxury      Midsize          Sedan
# 21                                    Luxury      Midsize          Sedan
# 22                                    Luxury      Midsize          Sedan
# 23                                    Luxury      Midsize          Wagon
# 24                                    Luxury      Midsize          Sedan
# 25                                    Luxury      Midsize          Sedan
# 26                                    Luxury      Midsize          Sedan
# 27                                    Luxury      Midsize          Wagon
# 28                                    Luxury      Midsize          Sedan
# 29                                    Luxury      Midsize          Sedan
# ...                                      ...          ...            ...
# 11884                     Luxury,Performance      Compact    Convertible
# 11885                     Luxury,Performance      Compact    Convertible
# 11886           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11887                     Luxury,Performance      Compact    Convertible
# 11888                     Luxury,Performance      Compact    Convertible
# 11889           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11890  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11891  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11892  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11893  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11894                     Luxury,Performance      Compact    Convertible
# 11895                Luxury,High-Performance      Compact    Convertible
# 11896                Luxury,High-Performance      Compact    Convertible
# 11897                     Luxury,Performance      Compact    Convertible
# 11898                Luxury,High-Performance      Compact    Convertible
# 11899                Luxury,High-Performance      Compact    Convertible
# 11900                Luxury,High-Performance      Compact    Convertible
# 11901                     Luxury,Performance      Compact    Convertible
# 11902                Luxury,High-Performance      Compact    Convertible
# 11903         Exotic,Luxury,High-Performance      Compact    Convertible
# 11904         Exotic,Luxury,High-Performance      Compact    Convertible
# 11905         Exotic,Luxury,High-Performance      Compact    Convertible
# 11906             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11907             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11908             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity    MSRP
# 0               26        19        3916   46135
# 1               28        19        3916   40650
# 2               28        20        3916   36350
# 3               28        18        3916   29450
# 4               28        18        3916   34500
# 5               28        18        3916   31200
# 6               26        17        3916   44100
# 7               28        20        3916   39300
# 8               28        18        3916   36900
# 9               27        18        3916   37200
# 10              28        20        3916   39600
# 11              28        19        3916   31500
# 12              28        19        3916   44400
# 13              28        19        3916   37200
# 14              28        19        3916   31500
# 15              25        18        3916   48250
# 16              28        20        3916   43550
# 17              24        17        3105    2000
# 18              24        17        3105    2000
# 19              20        16        3105    2000
# 20              24        17        3105    2000
# 21              21        16        3105    2000
# 22              24        17        3105    2000
# 23              20        16        3105    2000
# 24              24        17        3105    2000
# 25              24        17        3105    2000
# 26              21        16        3105    2000
# 27              21        16        3105    2000
# 28              22        16        3105    2000
# 29              22        17        3105    2000
# ...            ...       ...         ...     ...
# 11884           26        19        3916   37900
# 11885           25        18        3916   31300
# 11886           26        19        3916   37700
# 11887           26        19        3916   37900
# 11888           25        18        3916   31300
# 11889           26        19        3916   37700
# 11890           22        15        3916   50100
# 11891           22        15        3916   52100
# 11892           23        15        3916   50400
# 11893           23        15        3916   52400
# 11894           34        22        3916   48950
# 11895           26        19        3916   56950
# 11896           24        17        3916   65800
# 11897           34        22        3916   48950
# 11898           24        17        3916   56950
# 11899           24        17        3916   65800
# 11900           24        17        3916   57500
# 11901           34        22        3916   49700
# 11902           24        17        3916   66350
# 11903           19        12        3916  128000
# 11904           19        12        3916  130000
# 11905           19        12        3916  131500
# 11906           23        16         204   46020
# 11907           23        16         204   56570
# 11908           23        16         204   50520
# 11909           23        16         204   46120
# 11910           23        16         204   56670
# 11911           23        16         204   50620
# 11912           23        16         204   50920
# 11913           26        17          61   28995
#
# [11914 rows x 16 columns]

# %%
le=preprocessing.LabelEncoder()

# %%
df['Make']=le.fit_transform(df['Make'])

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0         4  1 Series M  2011     premium unleaded (required)      335.0
# 1         4    1 Series  2011     premium unleaded (required)      300.0
# 2         4    1 Series  2011     premium unleaded (required)      300.0
# 3         4    1 Series  2011     premium unleaded (required)      230.0
# 4         4    1 Series  2011     premium unleaded (required)      230.0
# 5         4    1 Series  2012     premium unleaded (required)      230.0
# 6         4    1 Series  2012     premium unleaded (required)      300.0
# 7         4    1 Series  2012     premium unleaded (required)      300.0
# 8         4    1 Series  2012     premium unleaded (required)      230.0
# 9         4    1 Series  2013     premium unleaded (required)      230.0
# 10        4    1 Series  2013     premium unleaded (required)      300.0
# 11        4    1 Series  2013     premium unleaded (required)      230.0
# 12        4    1 Series  2013     premium unleaded (required)      300.0
# 13        4    1 Series  2013     premium unleaded (required)      230.0
# 14        4    1 Series  2013     premium unleaded (required)      230.0
# 15        4    1 Series  2013     premium unleaded (required)      320.0
# 16        4    1 Series  2013     premium unleaded (required)      320.0
# 17        3         100  1992                regular unleaded      172.0
# 18        3         100  1992                regular unleaded      172.0
# 19        3         100  1992                regular unleaded      172.0
# 20        3         100  1992                regular unleaded      172.0
# 21        3         100  1992                regular unleaded      172.0
# 22        3         100  1993                regular unleaded      172.0
# 23        3         100  1993                regular unleaded      172.0
# 24        3         100  1993                regular unleaded      172.0
# 25        3         100  1993                regular unleaded      172.0
# 26        3         100  1993                regular unleaded      172.0
# 27        3         100  1994                regular unleaded      172.0
# 28        3         100  1994                regular unleaded      172.0
# 29        3         100  1994                regular unleaded      172.0
# ...     ...         ...   ...                             ...        ...
# 11884     4          Z3  2001     premium unleaded (required)      225.0
# 11885     4          Z3  2001     premium unleaded (required)      184.0
# 11886     4          Z3  2001     premium unleaded (required)      225.0
# 11887     4          Z3  2002     premium unleaded (required)      225.0
# 11888     4          Z3  2002     premium unleaded (required)      184.0
# 11889     4          Z3  2002     premium unleaded (required)      225.0
# 11890     4        Z4 M  2007     premium unleaded (required)      330.0
# 11891     4        Z4 M  2007     premium unleaded (required)      330.0
# 11892     4        Z4 M  2008     premium unleaded (required)      330.0
# 11893     4        Z4 M  2008     premium unleaded (required)      330.0
# 11894     4          Z4  2014     premium unleaded (required)      240.0
# 11895     4          Z4  2014     premium unleaded (required)      300.0
# 11896     4          Z4  2014     premium unleaded (required)      335.0
# 11897     4          Z4  2015     premium unleaded (required)      240.0
# 11898     4          Z4  2015     premium unleaded (required)      300.0
# 11899     4          Z4  2015     premium unleaded (required)      335.0
# 11900     4          Z4  2016     premium unleaded (required)      300.0
# 11901     4          Z4  2016     premium unleaded (required)      240.0
# 11902     4          Z4  2016     premium unleaded (required)      335.0
# 11903     4          Z8  2001     premium unleaded (required)      394.0
# 11904     4          Z8  2002     premium unleaded (required)      394.0
# 11905     4          Z8  2003     premium unleaded (required)      394.0
# 11906     0         ZDX  2011     premium unleaded (required)      300.0
# 11907     0         ZDX  2011     premium unleaded (required)      300.0
# 11908     0         ZDX  2011     premium unleaded (required)      300.0
# 11909     0         ZDX  2012     premium unleaded (required)      300.0
# 11910     0         ZDX  2012     premium unleaded (required)      300.0
# 11911     0         ZDX  2012     premium unleaded (required)      300.0
# 11912     0         ZDX  2013  premium unleaded (recommended)      300.0
# 11913    25      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# 5                   6.0            MANUAL   rear wheel drive              2.0
# 6                   6.0            MANUAL   rear wheel drive              2.0
# 7                   6.0            MANUAL   rear wheel drive              2.0
# 8                   6.0            MANUAL   rear wheel drive              2.0
# 9                   6.0            MANUAL   rear wheel drive              2.0
# 10                  6.0            MANUAL   rear wheel drive              2.0
# 11                  6.0            MANUAL   rear wheel drive              2.0
# 12                  6.0            MANUAL   rear wheel drive              2.0
# 13                  6.0            MANUAL   rear wheel drive              2.0
# 14                  6.0            MANUAL   rear wheel drive              2.0
# 15                  6.0            MANUAL   rear wheel drive              2.0
# 16                  6.0            MANUAL   rear wheel drive              2.0
# 17                  6.0            MANUAL  front wheel drive              4.0
# 18                  6.0            MANUAL  front wheel drive              4.0
# 19                  6.0         AUTOMATIC    all wheel drive              4.0
# 20                  6.0            MANUAL  front wheel drive              4.0
# 21                  6.0            MANUAL    all wheel drive              4.0
# 22                  6.0            MANUAL  front wheel drive              4.0
# 23                  6.0         AUTOMATIC    all wheel drive              4.0
# 24                  6.0            MANUAL  front wheel drive              4.0
# 25                  6.0            MANUAL  front wheel drive              4.0
# 26                  6.0            MANUAL    all wheel drive              4.0
# 27                  6.0         AUTOMATIC  front wheel drive              4.0
# 28                  6.0            MANUAL    all wheel drive              4.0
# 29                  6.0            MANUAL  front wheel drive              4.0
# ...                 ...               ...                ...              ...
# 11884               6.0            MANUAL   rear wheel drive              2.0
# 11885               6.0            MANUAL   rear wheel drive              2.0
# 11886               6.0            MANUAL   rear wheel drive              2.0
# 11887               6.0            MANUAL   rear wheel drive              2.0
# 11888               6.0            MANUAL   rear wheel drive              2.0
# 11889               6.0            MANUAL   rear wheel drive              2.0
# 11890               6.0            MANUAL   rear wheel drive              2.0
# 11891               6.0            MANUAL   rear wheel drive              2.0
# 11892               6.0            MANUAL   rear wheel drive              2.0
# 11893               6.0            MANUAL   rear wheel drive              2.0
# 11894               4.0            MANUAL   rear wheel drive              2.0
# 11895               6.0            MANUAL   rear wheel drive              2.0
# 11896               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11897               4.0            MANUAL   rear wheel drive              2.0
# 11898               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11899               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11900               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11901               4.0            MANUAL   rear wheel drive              2.0
# 11902               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11903               8.0            MANUAL   rear wheel drive              2.0
# 11904               8.0            MANUAL   rear wheel drive              2.0
# 11905               8.0            MANUAL   rear wheel drive              2.0
# 11906               6.0         AUTOMATIC    all wheel drive              4.0
# 11907               6.0         AUTOMATIC    all wheel drive              4.0
# 11908               6.0         AUTOMATIC    all wheel drive              4.0
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# 5                         Luxury,Performance      Compact          Coupe
# 6                         Luxury,Performance      Compact    Convertible
# 7                    Luxury,High-Performance      Compact          Coupe
# 8                                     Luxury      Compact    Convertible
# 9                                     Luxury      Compact    Convertible
# 10                   Luxury,High-Performance      Compact          Coupe
# 11                        Luxury,Performance      Compact          Coupe
# 12                        Luxury,Performance      Compact    Convertible
# 13                                    Luxury      Compact    Convertible
# 14                        Luxury,Performance      Compact          Coupe
# 15                   Luxury,High-Performance      Compact    Convertible
# 16                   Luxury,High-Performance      Compact          Coupe
# 17                                    Luxury      Midsize          Sedan
# 18                                    Luxury      Midsize          Sedan
# 19                                    Luxury      Midsize          Wagon
# 20                                    Luxury      Midsize          Sedan
# 21                                    Luxury      Midsize          Sedan
# 22                                    Luxury      Midsize          Sedan
# 23                                    Luxury      Midsize          Wagon
# 24                                    Luxury      Midsize          Sedan
# 25                                    Luxury      Midsize          Sedan
# 26                                    Luxury      Midsize          Sedan
# 27                                    Luxury      Midsize          Wagon
# 28                                    Luxury      Midsize          Sedan
# 29                                    Luxury      Midsize          Sedan
# ...                                      ...          ...            ...
# 11884                     Luxury,Performance      Compact    Convertible
# 11885                     Luxury,Performance      Compact    Convertible
# 11886           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11887                     Luxury,Performance      Compact    Convertible
# 11888                     Luxury,Performance      Compact    Convertible
# 11889           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11890  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11891  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11892  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11893  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11894                     Luxury,Performance      Compact    Convertible
# 11895                Luxury,High-Performance      Compact    Convertible
# 11896                Luxury,High-Performance      Compact    Convertible
# 11897                     Luxury,Performance      Compact    Convertible
# 11898                Luxury,High-Performance      Compact    Convertible
# 11899                Luxury,High-Performance      Compact    Convertible
# 11900                Luxury,High-Performance      Compact    Convertible
# 11901                     Luxury,Performance      Compact    Convertible
# 11902                Luxury,High-Performance      Compact    Convertible
# 11903         Exotic,Luxury,High-Performance      Compact    Convertible
# 11904         Exotic,Luxury,High-Performance      Compact    Convertible
# 11905         Exotic,Luxury,High-Performance      Compact    Convertible
# 11906             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11907             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11908             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity    MSRP
# 0               26        19        3916   46135
# 1               28        19        3916   40650
# 2               28        20        3916   36350
# 3               28        18        3916   29450
# 4               28        18        3916   34500
# 5               28        18        3916   31200
# 6               26        17        3916   44100
# 7               28        20        3916   39300
# 8               28        18        3916   36900
# 9               27        18        3916   37200
# 10              28        20        3916   39600
# 11              28        19        3916   31500
# 12              28        19        3916   44400
# 13              28        19        3916   37200
# 14              28        19        3916   31500
# 15              25        18        3916   48250
# 16              28        20        3916   43550
# 17              24        17        3105    2000
# 18              24        17        3105    2000
# 19              20        16        3105    2000
# 20              24        17        3105    2000
# 21              21        16        3105    2000
# 22              24        17        3105    2000
# 23              20        16        3105    2000
# 24              24        17        3105    2000
# 25              24        17        3105    2000
# 26              21        16        3105    2000
# 27              21        16        3105    2000
# 28              22        16        3105    2000
# 29              22        17        3105    2000
# ...            ...       ...         ...     ...
# 11884           26        19        3916   37900
# 11885           25        18        3916   31300
# 11886           26        19        3916   37700
# 11887           26        19        3916   37900
# 11888           25        18        3916   31300
# 11889           26        19        3916   37700
# 11890           22        15        3916   50100
# 11891           22        15        3916   52100
# 11892           23        15        3916   50400
# 11893           23        15        3916   52400
# 11894           34        22        3916   48950
# 11895           26        19        3916   56950
# 11896           24        17        3916   65800
# 11897           34        22        3916   48950
# 11898           24        17        3916   56950
# 11899           24        17        3916   65800
# 11900           24        17        3916   57500
# 11901           34        22        3916   49700
# 11902           24        17        3916   66350
# 11903           19        12        3916  128000
# 11904           19        12        3916  130000
# 11905           19        12        3916  131500
# 11906           23        16         204   46020
# 11907           23        16         204   56570
# 11908           23        16         204   50520
# 11909           23        16         204   46120
# 11910           23        16         204   56670
# 11911           23        16         204   50620
# 11912           23        16         204   50920
# 11913           26        17          61   28995
#
# [8084 rows x 16 columns]

# %%
df['Engine Fuel Type']=le.fit_transform(df['Engine Fuel Type'])

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df
# Out:
#        Make       Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         4  1 Series M  2011                 6      335.0               6.0
# 1         4    1 Series  2011                 6      300.0               6.0
# 2         4    1 Series  2011                 6      300.0               6.0
# 3         4    1 Series  2011                 6      230.0               6.0
# 4         4    1 Series  2011                 6      230.0               6.0
# 5         4    1 Series  2012                 6      230.0               6.0
# 6         4    1 Series  2012                 6      300.0               6.0
# 7         4    1 Series  2012                 6      300.0               6.0
# 8         4    1 Series  2012                 6      230.0               6.0
# 9         4    1 Series  2013                 6      230.0               6.0
# 10        4    1 Series  2013                 6      300.0               6.0
# 11        4    1 Series  2013                 6      230.0               6.0
# 12        4    1 Series  2013                 6      300.0               6.0
# 13        4    1 Series  2013                 6      230.0               6.0
# 14        4    1 Series  2013                 6      230.0               6.0
# 15        4    1 Series  2013                 6      320.0               6.0
# 16        4    1 Series  2013                 6      320.0               6.0
# 17        3         100  1992                 7      172.0               6.0
# 18        3         100  1992                 7      172.0               6.0
# 19        3         100  1992                 7      172.0               6.0
# 20        3         100  1992                 7      172.0               6.0
# 21        3         100  1992                 7      172.0               6.0
# 22        3         100  1993                 7      172.0               6.0
# 23        3         100  1993                 7      172.0               6.0
# 24        3         100  1993                 7      172.0               6.0
# 25        3         100  1993                 7      172.0               6.0
# 26        3         100  1993                 7      172.0               6.0
# 27        3         100  1994                 7      172.0               6.0
# 28        3         100  1994                 7      172.0               6.0
# 29        3         100  1994                 7      172.0               6.0
# ...     ...         ...   ...               ...        ...               ...
# 11884     4          Z3  2001                 6      225.0               6.0
# 11885     4          Z3  2001                 6      184.0               6.0
# 11886     4          Z3  2001                 6      225.0               6.0
# 11887     4          Z3  2002                 6      225.0               6.0
# 11888     4          Z3  2002                 6      184.0               6.0
# 11889     4          Z3  2002                 6      225.0               6.0
# 11890     4        Z4 M  2007                 6      330.0               6.0
# 11891     4        Z4 M  2007                 6      330.0               6.0
# 11892     4        Z4 M  2008                 6      330.0               6.0
# 11893     4        Z4 M  2008                 6      330.0               6.0
# 11894     4          Z4  2014                 6      240.0               4.0
# 11895     4          Z4  2014                 6      300.0               6.0
# 11896     4          Z4  2014                 6      335.0               6.0
# 11897     4          Z4  2015                 6      240.0               4.0
# 11898     4          Z4  2015                 6      300.0               6.0
# 11899     4          Z4  2015                 6      335.0               6.0
# 11900     4          Z4  2016                 6      300.0               6.0
# 11901     4          Z4  2016                 6      240.0               4.0
# 11902     4          Z4  2016                 6      335.0               6.0
# 11903     4          Z8  2001                 6      394.0               8.0
# 11904     4          Z8  2002                 6      394.0               8.0
# 11905     4          Z8  2003                 6      394.0               8.0
# 11906     0         ZDX  2011                 6      300.0               6.0
# 11907     0         ZDX  2011                 6      300.0               6.0
# 11908     0         ZDX  2011                 6      300.0               6.0
# 11909     0         ZDX  2012                 6      300.0               6.0
# 11910     0         ZDX  2012                 6      300.0               6.0
# 11911     0         ZDX  2012                 6      300.0               6.0
# 11912     0         ZDX  2013                 5      300.0               6.0
# 11913    25      Zephyr  2006                 7      221.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors  \
# 0                MANUAL   rear wheel drive              2.0
# 1                MANUAL   rear wheel drive              2.0
# 2                MANUAL   rear wheel drive              2.0
# 3                MANUAL   rear wheel drive              2.0
# 4                MANUAL   rear wheel drive              2.0
# 5                MANUAL   rear wheel drive              2.0
# 6                MANUAL   rear wheel drive              2.0
# 7                MANUAL   rear wheel drive              2.0
# 8                MANUAL   rear wheel drive              2.0
# 9                MANUAL   rear wheel drive              2.0
# 10               MANUAL   rear wheel drive              2.0
# 11               MANUAL   rear wheel drive              2.0
# 12               MANUAL   rear wheel drive              2.0
# 13               MANUAL   rear wheel drive              2.0
# 14               MANUAL   rear wheel drive              2.0
# 15               MANUAL   rear wheel drive              2.0
# 16               MANUAL   rear wheel drive              2.0
# 17               MANUAL  front wheel drive              4.0
# 18               MANUAL  front wheel drive              4.0
# 19            AUTOMATIC    all wheel drive              4.0
# 20               MANUAL  front wheel drive              4.0
# 21               MANUAL    all wheel drive              4.0
# 22               MANUAL  front wheel drive              4.0
# 23            AUTOMATIC    all wheel drive              4.0
# 24               MANUAL  front wheel drive              4.0
# 25               MANUAL  front wheel drive              4.0
# 26               MANUAL    all wheel drive              4.0
# 27            AUTOMATIC  front wheel drive              4.0
# 28               MANUAL    all wheel drive              4.0
# 29               MANUAL  front wheel drive              4.0
# ...                 ...                ...              ...
# 11884            MANUAL   rear wheel drive              2.0
# 11885            MANUAL   rear wheel drive              2.0
# 11886            MANUAL   rear wheel drive              2.0
# 11887            MANUAL   rear wheel drive              2.0
# 11888            MANUAL   rear wheel drive              2.0
# 11889            MANUAL   rear wheel drive              2.0
# 11890            MANUAL   rear wheel drive              2.0
# 11891            MANUAL   rear wheel drive              2.0
# 11892            MANUAL   rear wheel drive              2.0
# 11893            MANUAL   rear wheel drive              2.0
# 11894            MANUAL   rear wheel drive              2.0
# 11895            MANUAL   rear wheel drive              2.0
# 11896  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11897            MANUAL   rear wheel drive              2.0
# 11898  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11899  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11900  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11901            MANUAL   rear wheel drive              2.0
# 11902  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11903            MANUAL   rear wheel drive              2.0
# 11904            MANUAL   rear wheel drive              2.0
# 11905            MANUAL   rear wheel drive              2.0
# 11906         AUTOMATIC    all wheel drive              4.0
# 11907         AUTOMATIC    all wheel drive              4.0
# 11908         AUTOMATIC    all wheel drive              4.0
# 11909         AUTOMATIC    all wheel drive              4.0
# 11910         AUTOMATIC    all wheel drive              4.0
# 11911         AUTOMATIC    all wheel drive              4.0
# 11912         AUTOMATIC    all wheel drive              4.0
# 11913         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# 5                         Luxury,Performance      Compact          Coupe
# 6                         Luxury,Performance      Compact    Convertible
# 7                    Luxury,High-Performance      Compact          Coupe
# 8                                     Luxury      Compact    Convertible
# 9                                     Luxury      Compact    Convertible
# 10                   Luxury,High-Performance      Compact          Coupe
# 11                        Luxury,Performance      Compact          Coupe
# 12                        Luxury,Performance      Compact    Convertible
# 13                                    Luxury      Compact    Convertible
# 14                        Luxury,Performance      Compact          Coupe
# 15                   Luxury,High-Performance      Compact    Convertible
# 16                   Luxury,High-Performance      Compact          Coupe
# 17                                    Luxury      Midsize          Sedan
# 18                                    Luxury      Midsize          Sedan
# 19                                    Luxury      Midsize          Wagon
# 20                                    Luxury      Midsize          Sedan
# 21                                    Luxury      Midsize          Sedan
# 22                                    Luxury      Midsize          Sedan
# 23                                    Luxury      Midsize          Wagon
# 24                                    Luxury      Midsize          Sedan
# 25                                    Luxury      Midsize          Sedan
# 26                                    Luxury      Midsize          Sedan
# 27                                    Luxury      Midsize          Wagon
# 28                                    Luxury      Midsize          Sedan
# 29                                    Luxury      Midsize          Sedan
# ...                                      ...          ...            ...
# 11884                     Luxury,Performance      Compact    Convertible
# 11885                     Luxury,Performance      Compact    Convertible
# 11886           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11887                     Luxury,Performance      Compact    Convertible
# 11888                     Luxury,Performance      Compact    Convertible
# 11889           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11890  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11891  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11892  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11893  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11894                     Luxury,Performance      Compact    Convertible
# 11895                Luxury,High-Performance      Compact    Convertible
# 11896                Luxury,High-Performance      Compact    Convertible
# 11897                     Luxury,Performance      Compact    Convertible
# 11898                Luxury,High-Performance      Compact    Convertible
# 11899                Luxury,High-Performance      Compact    Convertible
# 11900                Luxury,High-Performance      Compact    Convertible
# 11901                     Luxury,Performance      Compact    Convertible
# 11902                Luxury,High-Performance      Compact    Convertible
# 11903         Exotic,Luxury,High-Performance      Compact    Convertible
# 11904         Exotic,Luxury,High-Performance      Compact    Convertible
# 11905         Exotic,Luxury,High-Performance      Compact    Convertible
# 11906             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11907             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11908             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity    MSRP
# 0               26        19        3916   46135
# 1               28        19        3916   40650
# 2               28        20        3916   36350
# 3               28        18        3916   29450
# 4               28        18        3916   34500
# 5               28        18        3916   31200
# 6               26        17        3916   44100
# 7               28        20        3916   39300
# 8               28        18        3916   36900
# 9               27        18        3916   37200
# 10              28        20        3916   39600
# 11              28        19        3916   31500
# 12              28        19        3916   44400
# 13              28        19        3916   37200
# 14              28        19        3916   31500
# 15              25        18        3916   48250
# 16              28        20        3916   43550
# 17              24        17        3105    2000
# 18              24        17        3105    2000
# 19              20        16        3105    2000
# 20              24        17        3105    2000
# 21              21        16        3105    2000
# 22              24        17        3105    2000
# 23              20        16        3105    2000
# 24              24        17        3105    2000
# 25              24        17        3105    2000
# 26              21        16        3105    2000
# 27              21        16        3105    2000
# 28              22        16        3105    2000
# 29              22        17        3105    2000
# ...            ...       ...         ...     ...
# 11884           26        19        3916   37900
# 11885           25        18        3916   31300
# 11886           26        19        3916   37700
# 11887           26        19        3916   37900
# 11888           25        18        3916   31300
# 11889           26        19        3916   37700
# 11890           22        15        3916   50100
# 11891           22        15        3916   52100
# 11892           23        15        3916   50400
# 11893           23        15        3916   52400
# 11894           34        22        3916   48950
# 11895           26        19        3916   56950
# 11896           24        17        3916   65800
# 11897           34        22        3916   48950
# 11898           24        17        3916   56950
# 11899           24        17        3916   65800
# 11900           24        17        3916   57500
# 11901           34        22        3916   49700
# 11902           24        17        3916   66350
# 11903           19        12        3916  128000
# 11904           19        12        3916  130000
# 11905           19        12        3916  131500
# 11906           23        16         204   46020
# 11907           23        16         204   56570
# 11908           23        16         204   50520
# 11909           23        16         204   46120
# 11910           23        16         204   56670
# 11911           23        16         204   50620
# 11912           23        16         204   50920
# 11913           26        17          61   28995
#
# [8084 rows x 16 columns]

# %%
df['Model']=le.fit_transform(df['Model'])

# %%
df['Transmission Type']=le.fit_transform(df['Transmission Type'])

# %%
df['Driven_Wheels']=le.fit_transform(df['Driven_Wheels'])

# %%
df['Market Category']=le.fit_transform(df['Market Category'])

# %%
df['Vehicle Size']=le.fit_transform(df['Vehicle Size'])

# %%
df['Vehicle Style']=le.fit_transform(df['Vehicle Style'])

# %%
df['Year']=le.fit_transform(df['Year'])

# %%
df
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         4      1    21                 6      335.0               6.0
# 1         4      0    21                 6      300.0               6.0
# 2         4      0    21                 6      300.0               6.0
# 3         4      0    21                 6      230.0               6.0
# 4         4      0    21                 6      230.0               6.0
# 5         4      0    22                 6      230.0               6.0
# 6         4      0    22                 6      300.0               6.0
# 7         4      0    22                 6      300.0               6.0
# 8         4      0    22                 6      230.0               6.0
# 9         4      0    23                 6      230.0               6.0
# 10        4      0    23                 6      300.0               6.0
# 11        4      0    23                 6      230.0               6.0
# 12        4      0    23                 6      300.0               6.0
# 13        4      0    23                 6      230.0               6.0
# 14        4      0    23                 6      230.0               6.0
# 15        4      0    23                 6      320.0               6.0
# 16        4      0    23                 6      320.0               6.0
# 17        3      2     2                 7      172.0               6.0
# 18        3      2     2                 7      172.0               6.0
# 19        3      2     2                 7      172.0               6.0
# 20        3      2     2                 7      172.0               6.0
# 21        3      2     2                 7      172.0               6.0
# 22        3      2     3                 7      172.0               6.0
# 23        3      2     3                 7      172.0               6.0
# 24        3      2     3                 7      172.0               6.0
# 25        3      2     3                 7      172.0               6.0
# 26        3      2     3                 7      172.0               6.0
# 27        3      2     4                 7      172.0               6.0
# 28        3      2     4                 7      172.0               6.0
# 29        3      2     4                 7      172.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11884     4    699    11                 6      225.0               6.0
# 11885     4    699    11                 6      184.0               6.0
# 11886     4    699    11                 6      225.0               6.0
# 11887     4    699    12                 6      225.0               6.0
# 11888     4    699    12                 6      184.0               6.0
# 11889     4    699    12                 6      225.0               6.0
# 11890     4    701    17                 6      330.0               6.0
# 11891     4    701    17                 6      330.0               6.0
# 11892     4    701    18                 6      330.0               6.0
# 11893     4    701    18                 6      330.0               6.0
# 11894     4    700    24                 6      240.0               4.0
# 11895     4    700    24                 6      300.0               6.0
# 11896     4    700    24                 6      335.0               6.0
# 11897     4    700    25                 6      240.0               4.0
# 11898     4    700    25                 6      300.0               6.0
# 11899     4    700    25                 6      335.0               6.0
# 11900     4    700    26                 6      300.0               6.0
# 11901     4    700    26                 6      240.0               4.0
# 11902     4    700    26                 6      335.0               6.0
# 11903     4    702    11                 6      394.0               8.0
# 11904     4    702    12                 6      394.0               8.0
# 11905     4    702    13                 6      394.0               8.0
# 11906     0    703    21                 6      300.0               6.0
# 11907     0    703    21                 6      300.0               6.0
# 11908     0    703    21                 6      300.0               6.0
# 11909     0    703    22                 6      300.0               6.0
# 11910     0    703    22                 6      300.0               6.0
# 11911     0    703    22                 6      300.0               6.0
# 11912     0    703    23                 5      300.0               6.0
# 11913    25    704    16                 7      221.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 0                      3              3              2.0               37
# 1                      3              3              2.0               66
# 2                      3              3              2.0               63
# 3                      3              3              2.0               66
# 4                      3              3              2.0               62
# 5                      3              3              2.0               66
# 6                      3              3              2.0               66
# 7                      3              3              2.0               63
# 8                      3              3              2.0               62
# 9                      3              3              2.0               62
# 10                     3              3              2.0               63
# 11                     3              3              2.0               66
# 12                     3              3              2.0               66
# 13                     3              3              2.0               62
# 14                     3              3              2.0               66
# 15                     3              3              2.0               63
# 16                     3              3              2.0               63
# 17                     3              2              4.0               62
# 18                     3              2              4.0               62
# 19                     1              0              4.0               62
# 20                     3              2              4.0               62
# 21                     3              0              4.0               62
# 22                     3              2              4.0               62
# 23                     1              0              4.0               62
# 24                     3              2              4.0               62
# 25                     3              2              4.0               62
# 26                     3              0              4.0               62
# 27                     1              2              4.0               62
# 28                     3              0              4.0               62
# 29                     3              2              4.0               62
# ...                  ...            ...              ...              ...
# 11884                  3              3              2.0               66
# 11885                  3              3              2.0               66
# 11886                  3              3              2.0               58
# 11887                  3              3              2.0               66
# 11888                  3              3              2.0               66
# 11889                  3              3              2.0               58
# 11890                  3              3              2.0               37
# 11891                  3              3              2.0               37
# 11892                  3              3              2.0               37
# 11893                  3              3              2.0               37
# 11894                  3              3              2.0               66
# 11895                  3              3              2.0               63
# 11896                  0              3              2.0               63
# 11897                  3              3              2.0               66
# 11898                  0              3              2.0               63
# 11899                  0              3              2.0               63
# 11900                  0              3              2.0               63
# 11901                  3              3              2.0               66
# 11902                  0              3              2.0               63
# 11903                  3              3              2.0               32
# 11904                  3              3              2.0               32
# 11905                  3              3              2.0               32
# 11906                  1              0              4.0               13
# 11907                  1              0              4.0               13
# 11908                  1              0              4.0               13
# 11909                  1              0              4.0               13
# 11910                  1              0              4.0               13
# 11911                  1              0              4.0               13
# 11912                  1              0              4.0               13
# 11913                  1              2              4.0               62
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 0                 0              8           26        19        3916   46135
# 1                 0              6           28        19        3916   40650
# 2                 0              8           28        20        3916   36350
# 3                 0              8           28        18        3916   29450
# 4                 0              6           28        18        3916   34500
# 5                 0              8           28        18        3916   31200
# 6                 0              6           26        17        3916   44100
# 7                 0              8           28        20        3916   39300
# 8                 0              6           28        18        3916   36900
# 9                 0              6           27        18        3916   37200
# 10                0              8           28        20        3916   39600
# 11                0              8           28        19        3916   31500
# 12                0              6           28        19        3916   44400
# 13                0              6           28        19        3916   37200
# 14                0              8           28        19        3916   31500
# 15                0              6           25        18        3916   48250
# 16                0              8           28        20        3916   43550
# 17                2             14           24        17        3105    2000
# 18                2             14           24        17        3105    2000
# 19                2             15           20        16        3105    2000
# 20                2             14           24        17        3105    2000
# 21                2             14           21        16        3105    2000
# 22                2             14           24        17        3105    2000
# 23                2             15           20        16        3105    2000
# 24                2             14           24        17        3105    2000
# 25                2             14           24        17        3105    2000
# 26                2             14           21        16        3105    2000
# 27                2             15           21        16        3105    2000
# 28                2             14           22        16        3105    2000
# 29                2             14           22        17        3105    2000
# ...             ...            ...          ...       ...         ...     ...
# 11884             0              6           26        19        3916   37900
# 11885             0              6           25        18        3916   31300
# 11886             0              0           26        19        3916   37700
# 11887             0              6           26        19        3916   37900
# 11888             0              6           25        18        3916   31300
# 11889             0              0           26        19        3916   37700
# 11890             0              8           22        15        3916   50100
# 11891             0              6           22        15        3916   52100
# 11892             0              8           23        15        3916   50400
# 11893             0              6           23        15        3916   52400
# 11894             0              6           34        22        3916   48950
# 11895             0              6           26        19        3916   56950
# 11896             0              6           24        17        3916   65800
# 11897             0              6           34        22        3916   48950
# 11898             0              6           24        17        3916   56950
# 11899             0              6           24        17        3916   65800
# 11900             0              6           24        17        3916   57500
# 11901             0              6           34        22        3916   49700
# 11902             0              6           24        17        3916   66350
# 11903             0              6           19        12        3916  128000
# 11904             0              6           19        12        3916  130000
# 11905             0              6           19        12        3916  131500
# 11906             2              2           23        16         204   46020
# 11907             2              2           23        16         204   56570
# 11908             2              2           23        16         204   50520
# 11909             2              2           23        16         204   46120
# 11910             2              2           23        16         204   56670
# 11911             2              2           23        16         204   50620
# 11912             2              2           23        16         204   50920
# 11913             2             14           26        17          61   28995
#
# [8084 rows x 16 columns]

# %%
data=df.corr()

# %%
df.corr()
# Out:
#                        Make     Model      Year  Engine Fuel Type  Engine HP  \
# Make               1.000000  0.019650 -0.072013          0.097175  -0.244641
# Model              0.019650  1.000000  0.117518          0.011694  -0.005805
# Year              -0.072013  0.117518  1.000000         -0.223699   0.244256
# Engine Fuel Type   0.097175  0.011694 -0.223699          1.000000  -0.141533
# Engine HP         -0.244641 -0.005805  0.244256         -0.141533   1.000000
# Engine Cylinders  -0.271241  0.037946 -0.046552         -0.091385   0.811390
# Transmission Type  0.071735 -0.104630 -0.296359          0.094828  -0.143087
# Driven_Wheels     -0.037006 -0.108015 -0.179900         -0.012151   0.023640
# Number of Doors    0.035730  0.160707  0.182905          0.019163  -0.196042
# Market Category   -0.000515 -0.221727 -0.194360         -0.036931   0.014851
# Vehicle Size      -0.100201  0.052456  0.108599         -0.046801   0.182572
# Vehicle Style     -0.151170 -0.103285 -0.037100         -0.182134   0.196905
# highway MPG        0.126118 -0.083787  0.216441         -0.054397  -0.473019
# city mpg           0.169311 -0.017479  0.180041         -0.013362  -0.512779
# Popularity        -0.316756 -0.119296  0.118304         -0.060706   0.038012
# MSRP              -0.114350 -0.025186  0.133684         -0.069377   0.656662
#
#                    Engine Cylinders  Transmission Type  Driven_Wheels  \
# Make                      -0.271241           0.071735      -0.037006
# Model                      0.037946          -0.104630      -0.108015
# Year                      -0.046552          -0.296359      -0.179900
# Engine Fuel Type          -0.091385           0.094828      -0.012151
# Engine HP                  0.811390          -0.143087       0.023640
# Engine Cylinders           1.000000          -0.128096       0.124095
# Transmission Type         -0.128096           1.000000       0.194463
# Driven_Wheels              0.124095           0.194463       1.000000
# Number of Doors           -0.178578          -0.309936      -0.308930
# Market Category            0.011351           0.170818       0.290155
# Vehicle Size               0.170356          -0.283638      -0.152253
# Vehicle Style              0.173228          -0.125292       0.103068
# highway MPG               -0.603237           0.050691       0.006329
# city mpg                  -0.615459           0.029427      -0.013054
# Popularity                 0.014825          -0.012272       0.014815
# MSRP                       0.589185          -0.140910       0.001563
#
#                    Number of Doors  Market Category  Vehicle Size  \
# Make                      0.035730        -0.000515     -0.100201
# Model                     0.160707        -0.221727      0.052456
# Year                      0.182905        -0.194360      0.108599
# Engine Fuel Type          0.019163        -0.036931     -0.046801
# Engine HP                -0.196042         0.014851      0.182572
# Engine Cylinders         -0.178578         0.011351      0.170356
# Transmission Type        -0.309936         0.170818     -0.283638
# Driven_Wheels            -0.308930         0.290155     -0.152253
# Number of Doors           1.000000        -0.264123      0.317554
# Market Category          -0.264123         1.000000     -0.079693
# Vehicle Size              0.317554        -0.079693      1.000000
# Vehicle Style             0.171679         0.384504      0.283763
# highway MPG               0.103413         0.125265     -0.142015
# city mpg                  0.140205         0.075341     -0.164940
# Popularity               -0.040450        -0.040923     -0.000691
# MSRP                     -0.184699        -0.057530      0.007245
#
#                    Vehicle Style  highway MPG  city mpg  Popularity      MSRP
# Make                   -0.151170     0.126118  0.169311   -0.316756 -0.114350
# Model                  -0.103285    -0.083787 -0.017479   -0.119296 -0.025186
# Year                   -0.037100     0.216441  0.180041    0.118304  0.133684
# Engine Fuel Type       -0.182134    -0.054397 -0.013362   -0.060706 -0.069377
# Engine HP               0.196905    -0.473019 -0.512779    0.038012  0.656662
# Engine Cylinders        0.173228    -0.603237 -0.615459    0.014825  0.589185
# Transmission Type      -0.125292     0.050691  0.029427   -0.012272 -0.140910
# Driven_Wheels           0.103068     0.006329 -0.013054    0.014815  0.001563
# Number of Doors         0.171679     0.103413  0.140205   -0.040450 -0.184699
# Market Category         0.384504     0.125265  0.075341   -0.040923 -0.057530
# Vehicle Size            0.283763    -0.142015 -0.164940   -0.000691  0.007245
# Vehicle Style           1.000000    -0.078839 -0.143671    0.079270  0.068448
# highway MPG            -0.078839     1.000000  0.821349    0.032504 -0.257585
# city mpg               -0.143671     0.821349  1.000000    0.037057 -0.268003
# Popularity              0.079270     0.032504  0.037057    1.000000 -0.052477
# MSRP                    0.068448    -0.257585 -0.268003   -0.052477  1.000000

# %%
abs(df.corr())
# Out:
#                        Make     Model      Year  Engine Fuel Type  Engine HP  \
# Make               1.000000  0.019650  0.072013          0.097175   0.244641
# Model              0.019650  1.000000  0.117518          0.011694   0.005805
# Year               0.072013  0.117518  1.000000          0.223699   0.244256
# Engine Fuel Type   0.097175  0.011694  0.223699          1.000000   0.141533
# Engine HP          0.244641  0.005805  0.244256          0.141533   1.000000
# Engine Cylinders   0.271241  0.037946  0.046552          0.091385   0.811390
# Transmission Type  0.071735  0.104630  0.296359          0.094828   0.143087
# Driven_Wheels      0.037006  0.108015  0.179900          0.012151   0.023640
# Number of Doors    0.035730  0.160707  0.182905          0.019163   0.196042
# Market Category    0.000515  0.221727  0.194360          0.036931   0.014851
# Vehicle Size       0.100201  0.052456  0.108599          0.046801   0.182572
# Vehicle Style      0.151170  0.103285  0.037100          0.182134   0.196905
# highway MPG        0.126118  0.083787  0.216441          0.054397   0.473019
# city mpg           0.169311  0.017479  0.180041          0.013362   0.512779
# Popularity         0.316756  0.119296  0.118304          0.060706   0.038012
# MSRP               0.114350  0.025186  0.133684          0.069377   0.656662
#
#                    Engine Cylinders  Transmission Type  Driven_Wheels  \
# Make                       0.271241           0.071735       0.037006
# Model                      0.037946           0.104630       0.108015
# Year                       0.046552           0.296359       0.179900
# Engine Fuel Type           0.091385           0.094828       0.012151
# Engine HP                  0.811390           0.143087       0.023640
# Engine Cylinders           1.000000           0.128096       0.124095
# Transmission Type          0.128096           1.000000       0.194463
# Driven_Wheels              0.124095           0.194463       1.000000
# Number of Doors            0.178578           0.309936       0.308930
# Market Category            0.011351           0.170818       0.290155
# Vehicle Size               0.170356           0.283638       0.152253
# Vehicle Style              0.173228           0.125292       0.103068
# highway MPG                0.603237           0.050691       0.006329
# city mpg                   0.615459           0.029427       0.013054
# Popularity                 0.014825           0.012272       0.014815
# MSRP                       0.589185           0.140910       0.001563
#
#                    Number of Doors  Market Category  Vehicle Size  \
# Make                      0.035730         0.000515      0.100201
# Model                     0.160707         0.221727      0.052456
# Year                      0.182905         0.194360      0.108599
# Engine Fuel Type          0.019163         0.036931      0.046801
# Engine HP                 0.196042         0.014851      0.182572
# Engine Cylinders          0.178578         0.011351      0.170356
# Transmission Type         0.309936         0.170818      0.283638
# Driven_Wheels             0.308930         0.290155      0.152253
# Number of Doors           1.000000         0.264123      0.317554
# Market Category           0.264123         1.000000      0.079693
# Vehicle Size              0.317554         0.079693      1.000000
# Vehicle Style             0.171679         0.384504      0.283763
# highway MPG               0.103413         0.125265      0.142015
# city mpg                  0.140205         0.075341      0.164940
# Popularity                0.040450         0.040923      0.000691
# MSRP                      0.184699         0.057530      0.007245
#
#                    Vehicle Style  highway MPG  city mpg  Popularity      MSRP
# Make                    0.151170     0.126118  0.169311    0.316756  0.114350
# Model                   0.103285     0.083787  0.017479    0.119296  0.025186
# Year                    0.037100     0.216441  0.180041    0.118304  0.133684
# Engine Fuel Type        0.182134     0.054397  0.013362    0.060706  0.069377
# Engine HP               0.196905     0.473019  0.512779    0.038012  0.656662
# Engine Cylinders        0.173228     0.603237  0.615459    0.014825  0.589185
# Transmission Type       0.125292     0.050691  0.029427    0.012272  0.140910
# Driven_Wheels           0.103068     0.006329  0.013054    0.014815  0.001563
# Number of Doors         0.171679     0.103413  0.140205    0.040450  0.184699
# Market Category         0.384504     0.125265  0.075341    0.040923  0.057530
# Vehicle Size            0.283763     0.142015  0.164940    0.000691  0.007245
# Vehicle Style           1.000000     0.078839  0.143671    0.079270  0.068448
# highway MPG             0.078839     1.000000  0.821349    0.032504  0.257585
# city mpg                0.143671     0.821349  1.000000    0.037057  0.268003
# Popularity              0.079270     0.032504  0.037057    1.000000  0.052477
# MSRP                    0.068448     0.257585  0.268003    0.052477  1.000000

# %%
X1 = data['Engine HP']
X2 = data['Engine Cylinders']
Y = data['MSRP']

# Normalizing the data
X1 = np.array((X1 - X1.min())-(X1.max() - X1.min()))
X2 = np.array((X2 - X2.min())-(X2.max() - X2.min()))
Y = np.array((Y - Y.min())-(Y.max() - Y.min()))

# %%
x1_train, x1_test, x2_train, x2_test, y_train, y_test = train_test_split(X1, X2, Y, test_size=0.2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1_train, x2_train, y_train, 'g.')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1_test, x2_test, y_test, 'g.')

# %%
def hypothesis(a,b,c,x1,x2):
    return a * x1 + b * x2 + c

# %%
def error(a,b,c,x1,x2,y):
    e = 0
    m = len(x1)
    for i in range(m):
        e += np.power((hypothesis(a,b,c,x1[i],x2[i]) - y[i]), 2)
    
    return (1/(2*m)) * e

# %%
def step_gradient(a,b,c,x1,x2,y,learning_rate):
    grad_a = 0
    grad_b = 0
    grad_c = 0
    m = len(x1)
    for i in range(m):
        grad_a += 2/m * (hypothesis(a,b,c,x1[i],x2[i]) - y[i]) * x1[i]
        grad_b += 2/m * (hypothesis(a,b,c,x1[i],x2[i]) - y[i]) * x2[i]
        grad_c += 2/m * (hypothesis(a,b,c,x1[i],x2[i]) - y[i])
        
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    c = c - (grad_c * learning_rate)
    
    return a, b, c

# %%
def descend(initial_a, initial_b, initial_c, x1, x2, y, learning_rate, iterations):
    a = initial_a
    b = initial_b
    c = initial_c
    for i in range(iterations):
        e = error(a, b, c, x1, x2, y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}, c: {c}")
        
        a, b, c = step_gradient(a, b, c, x1, x2, y, learning_rate)

    return a, b, c

# %%
a = 0
b = 1
c = 1
learning_rate = 0.01
iterations = 10000

final_a, final_b, final_c = descend(a, b, c, x1_train, x2_train, y_train, learning_rate, iterations)
# Out:
# Error: 0.49622942942968873, a: 0, b: 1, c: 1
# Error: 0.018433833350808088, a: 0.006796718073367241, b: 0.7462881439115063, c: -0.1821166731631972
# Error: 0.01700266711145666, a: 0.10171107081456794, b: 0.6184445647171273, c: -0.22218945491440975
# Error: 0.01607127374098892, a: 0.19967892934280548, b: 0.5236073724794926, c: -0.2240770545075361
# Error: 0.015368246197066913, a: 0.28550683470059507, b: 0.4419249790181185, c: -0.22423895359799556
# Error: 0.014837365565128071, a: 0.36012124694883374, b: 0.3709769225375407, c: -0.22431327887444694
# Error: 0.014436478617220635, a: 0.42496148848865295, b: 0.30932556224158686, c: -0.22437488755545282
# Error: 0.014133754547397185, a: 0.4813067796012158, b: 0.25575149150694365, c: -0.22442829088667757
# Error: 0.013905156777054265, a: 0.5302700221021686, b: 0.2091964050537641, c: -0.22447469160357938
# Error: 0.013732534426158178, a: 0.5728183688725261, b: 0.1687407111751481, c: -0.22451501288325734

# %%
print(error(a, b, c, x1_train, x2_train, y_train))
print(error(final_a, final_b, final_c, x1_train, x2_train, y_train))
print(error(final_a, final_b, final_c, x1_test, x2_test, y_test))
# Out:
# 0.49622942942968873
# 0.013602181116131613
# 0.002610507625241883
